# %% [markdown]
# <a href="https://colab.research.google.com/github/keithvtls/AIDA-Activities/blob/main/CS5-Dataset%20Development/58021_DatasetDevelopment_DataHalaman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Development
#
# $_{\text{© Data Halaman: C. Canoza, I.J. Timbungco, N.K. Vitales, S.C. Zarraga | 2022 | Fudamentals of Artificial Intelligence and Data Analytics}}$

# %% [markdown]
# ## Importing Libraries & Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# the path is connected to the github just run this
# it's not needed to connect to the gdrive
research_data_path ='https://github.com/keithvtls/AIDA-Activities/raw/main/CS5-Dataset%20Development/A%20Survey%20on%20%E2%80%9CHow%20Does%20Lack%20of%20Traffic%20Signs%2C%20Traffic%20Lights%2C%20and%20Traffic%20Enforcers%20Affect%20the%20Probability%20of%20the%20Driver%20Possibly%20Getting%20Into%20an%20Accident.%E2%80%9D.csv'

# use in displaying the spreadsheet to pandas
research_data_path = pd.read_csv(research_data_path)

# %%
# copy of data
research_data_df = research_data_path.copy()
research_data_df
# Out:
#                        Timestamp                          Username  \
# 0    2022/02/23 4:48:24 PM GMT+8           ragabkhaled11@gmail.com
# 1    2022/02/23 6:50:21 PM GMT+8                  jansfc@gmail.com
# 2    2022/02/23 8:13:55 PM GMT+8         jasonsiriban513@yahoo.com
# 3    2022/02/23 8:48:45 PM GMT+8  jmalcance1@student.fatima.edu.ph
# 4    2022/02/23 8:56:54 PM GMT+8             acfabro1234@gmail.com
# 5    2022/02/23 9:18:57 PM GMT+8              warlocko.b@gmail.com
# 6   2022/02/23 10:45:49 PM GMT+8         danica.nuesca11@gmail.com
# 7    2022/02/24 6:59:39 AM GMT+8             juvisiriban@yahoo.com
# 8    2022/02/25 8:38:32 AM GMT+8              ryanmfloro@gmail.com
# 9    2022/02/26 8:20:29 PM GMT+8            designs.0801@gmail.com
# 10   2022/02/26 8:25:56 PM GMT+8          sonrey.reyes01@gmail.com
# 11   2022/02/26 8:33:25 PM GMT+8           petmalureliza@gmail.com
# 12   2022/02/26 8:42:34 PM GMT+8             khatsuzawaa@gmail.com
# ...

# %% [markdown]
# ## Behind the Dataset

# %% [markdown]
# **Motivation for creating the dataset**
#
#
# *   The dataset that had been used for this activity is the previous survey form that download the data into .csv file, for there is already data that had been gathered that which the questionnaire is made by the members, the group had agreed that the data will be using is from the first topic. The data that had been gathered is answered by different individuals that which became the dataset for this activity.
#
# **Elicitation plan used in collecting the data**
#
#
#
# *   In the first topic, the group wanted to find out whether the “Lack of Traffic Signs/Road Signs, Traffic Lights and Traffic Enforcers Affects the Probability of the Driver Possibly Getting Into an Accident” that became the analytics question. It is also a hypothesis that there is a relation between drivers that gets into an accident and the lack of traffic signs/road signs, traffic lights, and traffic enforcers. The stakeholder has identified which are the drivers that are made by a stakeholder mapping. along with that, the questionnaire is made for its survey.
#
# **Dataset and information on the data**
#
#
# *  The dataset consists of the driver's age, when is the last driver's license renewal date, type of license, classification of the vehicle that the driver use is class 1 (Car/Jeepney/Van/Pick-up/Motorcycle), class 2 (Bus/Truck/2 Axles and height of more than 7.5 feet), and class 3 (Large Truck/ Large Truck with Trailer/ 3 or more Axles and height greater than 7.5 feet), types of vehicle (public or private), if the driver has owned a car or not, how many years of driving experience, that falls in drivers characteristics. There is also in the dataset if the driver does attend a driving school in which there is a refresher or beginner wherein in the beginner there is no knowledge when it comes to driving, on the other hand, the refresher has a piece of knowledge or prior knowledge of driving that only needs refreshment to be ready on road. Also in the dataset, if the drivers have involvement in an accident and how often does the driver get involved in an accident. And whether is the traffic signs, traffic lights, and traffic enforcer is enough, is important, and is it well implemented in the respondent's area.

# %% [markdown]
# ## **About the dataset**

# %% [markdown]
# This dataset shows all the questions from the survey that the respondents are supposed to answer. Included here is the request for permission to answer the survey then followed by the questions connected to the research needed for the data gathering. The research dataset of the first column then shows all the questions, consisting of permissions, important information from the respondents, and the twenty specific questions for the research.

# %%
research_data_df.columns
# Out:
# Index(['Timestamp', 'Username', 'Permission to collect personal data',
#        'Permission to store personal data',
#        'Permission to use my personal data', 'Age',
#        'Last driver license renewal date: ', 'Type of license:',
#        'Classification of vehicle do you mostly drive',
#        'Type of Vehicle used most frequently',
#        'Do you own the vehicle you drive: ', 'Years of Driving:',
#        'Did you attend driving school:',
#        'If  you attended driving school are you:',
#        'How frequently do you drive in going to work',
#        'How frequently do you drive in your personal life (leisure, vacation, etc.)',
#        'Have you been involved in an accident?',
#        'If Yes, how often do you get involved in an accident?',
#        'What kind of accident have you been involved in:',
#        'How enough traffic signs in your area as: ',
#        'How enough traffic lights in your area as:',
# ...

# %% [markdown]
# ### With Email (using pandas.head)

# %% [markdown]
# The following dataset are the composition of all the questions from the researchers as well as the answers of the respondents. Here, it is divided into two parts, the use of pandas' heads and pandas' tails. The first part is the panda's head showing the answers of the first seventeen respondents given all the information from the survey they have answered. Below, the pandas tail is used to show the remaining fifteen answers of the respondents. It is also noticeable that the first seventeen respondents have given their email addresses which is shown from the dataset where the pandas head was used, and below where the pandas tail was used, the respondents considered not disclosing or using their emails.

# %%
research_data_df.head(17)
# Out:
#                        Timestamp                          Username  \
# 0    2022/02/23 4:48:24 PM GMT+8           ragabkhaled11@gmail.com
# 1    2022/02/23 6:50:21 PM GMT+8                  jansfc@gmail.com
# 2    2022/02/23 8:13:55 PM GMT+8         jasonsiriban513@yahoo.com
# 3    2022/02/23 8:48:45 PM GMT+8  jmalcance1@student.fatima.edu.ph
# 4    2022/02/23 8:56:54 PM GMT+8             acfabro1234@gmail.com
# 5    2022/02/23 9:18:57 PM GMT+8              warlocko.b@gmail.com
# 6   2022/02/23 10:45:49 PM GMT+8         danica.nuesca11@gmail.com
# 7    2022/02/24 6:59:39 AM GMT+8             juvisiriban@yahoo.com
# 8    2022/02/25 8:38:32 AM GMT+8              ryanmfloro@gmail.com
# 9    2022/02/26 8:20:29 PM GMT+8            designs.0801@gmail.com
# 10   2022/02/26 8:25:56 PM GMT+8          sonrey.reyes01@gmail.com
# 11   2022/02/26 8:33:25 PM GMT+8           petmalureliza@gmail.com
# 12   2022/02/26 8:42:34 PM GMT+8             khatsuzawaa@gmail.com
# ...

# %% [markdown]
# ### Without Email (using pandas.tail)

# %%
research_data_df.tail(15)
# Out:
#                        Timestamp Username  \
# 17  2022/03/01 11:47:22 AM GMT+8      NaN
# 18  2022/03/01 11:52:28 AM GMT+8      NaN
# 19  2022/03/01 11:54:17 AM GMT+8      NaN
# 20  2022/03/01 11:56:57 AM GMT+8      NaN
# 21  2022/03/01 11:59:47 AM GMT+8      NaN
# 22  2022/03/01 11:59:56 AM GMT+8      NaN
# 23  2022/03/01 12:03:56 PM GMT+8      NaN
# 24  2022/03/01 12:11:04 PM GMT+8      NaN
# 25  2022/03/01 12:11:26 PM GMT+8      NaN
# 26  2022/03/01 12:13:36 PM GMT+8      NaN
# 27  2022/03/01 12:14:58 PM GMT+8      NaN
# 28  2022/03/01 12:24:46 PM GMT+8      NaN
# 29  2022/03/01 12:26:14 PM GMT+8      NaN
# 30  2022/03/01 12:27:31 PM GMT+8      NaN
# 31  2022/03/01 12:40:06 PM GMT+8      NaN
#
#                   Permission to collect personal data  \
# 17  Yes, I give consent to the collection of my pe...
# 18  Yes, I give consent to the collection of my pe...
# 19  Yes, I give consent to the collection of my pe...
# 20  Yes, I give consent to the collection of my pe...
# ...

# %% [markdown]
# ### Driver Characteristics Sort by Age

# %%
  age_sort = research_data_df[['Age', 'Type of license:', 'Classification of vehicle do you mostly drive', 'Type of Vehicle used most frequently',
        'Do you own the vehicle you drive: ','Did you attend driving school:',
        'If  you attended driving school are you:',]].sort_values('Age')
age_sort
# Out:
#      Age                   Type of license:  \
# 13  20.0              Student driver permit
# 4   20.0  Non-professional driver’s license
# 0   21.0  Non-professional driver’s license
# 19  21.0  Non-professional driver’s license
# 10  21.0  Non-professional driver’s license
# 16  21.0  Non-professional driver’s license
# 3   21.0  Non-professional driver’s license
# 12  23.0  Non-professional driver’s license
# 14  25.0  Non-professional driver’s license
# 25  26.0      Professional driver’s license
# 28  29.0      Professional driver’s license
# 30  29.0  Non-professional driver’s license
# 21  30.0      Professional driver’s license
# 31  31.0  Non-professional driver’s license
# 27  32.0  Non-professional driver’s license
# 8   33.0  Non-professional driver’s license
# 24  35.0  Non-professional driver’s license
# 26  35.0      Professional driver’s license
# 15  36.0  Non-professional driver’s license
# 5   39.0      Professional driver’s license
# ...

# %% [markdown]
# ### Dropping of Respondents who didn't allow data to be collected

# %% [markdown]
# Below are the respondents who have decided not to disclose personal information most especially their names and locations. Age is required for it plays a huge role in determining some information needed for the research, as well as the answers for the survey itself.

# %%
age_sort.dropna(axis=0, how='all')
# Out:
#      Age                   Type of license:  \
# 13  20.0              Student driver permit
# 4   20.0  Non-professional driver’s license
# 0   21.0  Non-professional driver’s license
# 19  21.0  Non-professional driver’s license
# 10  21.0  Non-professional driver’s license
# 16  21.0  Non-professional driver’s license
# 3   21.0  Non-professional driver’s license
# 12  23.0  Non-professional driver’s license
# 14  25.0  Non-professional driver’s license
# 25  26.0      Professional driver’s license
# 28  29.0      Professional driver’s license
# 30  29.0  Non-professional driver’s license
# 21  30.0      Professional driver’s license
# 31  31.0  Non-professional driver’s license
# 27  32.0  Non-professional driver’s license
# 8   33.0  Non-professional driver’s license
# 24  35.0  Non-professional driver’s license
# 26  35.0      Professional driver’s license
# 15  36.0  Non-professional driver’s license
# 5   39.0      Professional driver’s license
# ...

# %% [markdown]
# The purpose of the dataset below is to identify the total number of answers regarding the type of license and type of vehicle. This counts the overall answers of the respondents to show the majority and the least in order to understand the driver’s perspective and choices.  Here, it shows that most of the respondents use non-professional driver’s license and the majority of the respondents uses class one vehicles on their journey.

# %% [markdown]
# ### Type of license, and Classfication of vehicle that mostly drive by drivers (using pandas.value_counts)

# %%
license_type_count = research_data_df['Type of license:'].value_counts()
license_type_count
# Out:
# Non-professional driver’s license    22
# Professional driver’s license         7
# Student driver permit                 1
# Name: Type of license:, dtype: int64

# %%
classification_count = research_data_df['Classification of vehicle do you mostly drive'].value_counts()
classification_count
# Out:
# Class 1 (Car/Jeepney/Van/Pick-up/Motorcycle)                                                          24
# Class 2 (Bus/Truck/2 Axles and height of more than 7.5 feet)                                           5
# Class 3 (Large Truck/ Large Truck with Trailer/ 3 or  more Axles and height greater than 7.5 feet)     1
# Name: Classification of vehicle do you mostly drive, dtype: int64

# %% [markdown]
# ## Visualization of Dataset

# %% [markdown]
# The dataset below in the pie chart shows the sorted ages of the respondents with age count. The numbers outside the pie chart are the age of the respondents given from the survey while the percentage inside the pie chart is the number count of ages summarized using percentage.

# %%
age_count = age_sort['Age'].value_counts()
# age_count.plot(xlabel="Age", ylabel="Count of Respondents", kind="bar", figsize=(15, 7))
age_count.plot(kind="pie", autopct='%1.1f%%', figsize=(10, 7))
plt.show()

# %% [markdown]
# The pie chart below shows the data of the license type count of the respondents. There are three choices of types of licenses given in the survey, it is then shown here that most of the respondents have non-professional driver’s licenses which 77.3% of them answered it and the followed by 23.3% for professional driver’s licenses and lastly, 3.3% only of the respondents use student driver’s permit.

# %%
license_type_count.plot(kind="pie", autopct='%1.1f%%', figsize=(10, 7))
plt.legend()

# %% [markdown]
# The last dataset in pie chart shows the visualization of respondents’ choice of vehicle classification. This counts the respondent’s answers and summarized them into percentages in order to plot them into a graph and visualize the data A huge part of the blue of the graph which consists of 80% of the respondent’s answers choosing class one has the majority of the answers chosen by the respondents and then followed by the orange part which has 16.7% which classified as class two, and only 3.3% for the green part which is class three.

# %%
classification_count.plot(kind="pie", autopct='%1.1f%%', figsize=(10, 10))
plt.legend()

# %% [markdown]
# The dataset below shows the result within the following questions, ‘How enough traffic signs, traffic lights, and traffic enforcers in your area?’. The result was shown in bar graph form in order to visualize the respondent’s answers. Here the percentage of ‘Not quite enough for the traffic signs has the majority of the respondent’s answers, the percentage of ‘Enough’ for the traffic lights has the highest bar, and also the percentage of ‘Enough’ for the traffic enforcers got the highest votes from the respondents.

# %%
enough_signs_count = research_data_df[['How enough traffic signs in your area as: ']].value_counts()
enough_lights_count = research_data_df[['How enough traffic lights in your area as:']].value_counts()
enough_enforcer_count = research_data_df[['How enough traffic enforcers in your area as:']].value_counts()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
enough_signs_count.plot(kind='bar',ax=axes[0],figsize=(20,5))
enough_lights_count.plot(kind='bar',ax=axes[1],figsize=(20,5))
enough_enforcer_count.plot(kind='bar',ax=axes[2],figsize=(20,5))

# %% [markdown]
# Below shows the dataset in bar graph visualizations of the following questions ‘How important are traffic signs, traffic lights, and traffic enforcers in your area?’. The bar graph represents the respondent’s answers and here, it shows that within the traffic signs, the majority of respondents have agreed that traffic signs are very important where it has the highest bar, as well as the traffic lights that the bar of ‘very important’ also has the majority of the answers and the last bar graph which shows the importance of traffic enforcers, the votes too close to each other but the ‘very important’ has still the highest bar.

# %%
importance_of_signs_count = research_data_path[['How important is traffic signs in your area:']].value_counts()
importance_of_lights_count = research_data_path[['How important of traffic lights in your area:']].value_counts()
importance_of_enforcers_count = research_data_path[['How important of traffic enforcers in your area:']].value_counts()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
importance_of_signs_count.plot(kind='bar',ax=axes[0],figsize=(20,5))
importance_of_lights_count.plot(kind='bar',ax=axes[1],figsize=(20,5))
importance_of_enforcers_count.plot(kind='bar',ax=axes[2],figsize=(20,5))

# %% [markdown]
# The last following bar graph is the visual representation of the question, ‘How well-implemented are the traffic signs, traffic lights, and traffic enforcers in your area?’. On the first bar graph which shows the implementation of traffic signs, the highest bar is within the answer ‘unsatisfied’. The next bar graph is about the implementation of traffic lights where the majority is within the answers of satisfaction and lastly, the last bar graph shows the votes of the respondents within the highest bar of ‘satisfied’. The overall dataset has a huge significance within the conducted study, “Lack of Traffic Signs/Road Signs, Traffic Lights and Traffic Enforcers Affects the Probability of the Driver Possibly Getting Into an Accident”, these are the data needed upon understanding the problems and to consider a solution that will also be helpful for the future researchers to for further studies.

# %%
implementation_of_signs_count = research_data_path[[' How well-implemented the traffic signs in your area:']].value_counts()
implementation_of_lights_count = research_data_path[[' How well-implemented the traffic enforcers in your area:']].value_counts()
implementation_of_enforcers_count = research_data_path[[' How well-implemented the traffic enforcers in your area:']].value_counts()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)
implementation_of_signs_count.plot(kind='bar',ax=axes[0],figsize=(20,5))
implementation_of_lights_count.plot(kind='bar',ax=axes[1],figsize=(20,5))
implementation_of_enforcers_count.plot(kind='bar',ax=axes[2],figsize=(20,5))
